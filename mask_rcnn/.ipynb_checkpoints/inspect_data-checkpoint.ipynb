# %% [markdown]
# # Mask R-CNN - Inspect Training Data
#
# <i> Sébastien Ohleyer </i>
#
# Inspect and visualize data loading and pre-processing code.

# %%
import os
import sys
import itertools
import math
import logging
import json
import re
import random
from collections import OrderedDict
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.lines as lines
from matplotlib.patches import Polygon

import utils
import visualize
from visualize import display_images
import model as modellib
from model import log

# %matplotlib inline 

ROOT_DIR = os.getcwd()
# Out:
# /Users/sebastienohleyer/anaconda3/envs/objreco_namr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# Using TensorFlow backend.

# %%
ROOT_DIR
# Out:
# '/Users/sebastienohleyer/Documents/ENS MVA/Object recognition/mask_rcnn'

# %% [markdown]
# ## Configurations

# %%
# MS COCO Dataset
import aerial
config = aerial.AerialConfig()
AERIAL_DIR = "../AerialImageDataset/"  # TODO: enter value here

# %% [markdown]
# ## Dataset

# %%
# Load dataset
dataset = aerial.AerialDataset()
dataset.load_aerial(AERIAL_DIR, "train")


print("Image Count: {}".format(len(dataset.image_ids)))
print("Class Count: {}".format(dataset.num_classes))
# Out:
# Image Count: 120
# Class Count: 2

# %%
dataset.image_ids
# Out:
# ['austin1.tif',
#  'austin10.tif',
#  'austin11.tif',
#  'austin12.tif',
#  'austin13.tif',
#  'austin14.tif',
#  'austin15.tif',
#  'austin16.tif',
#  'austin17.tif',
#  'austin18.tif',
#  'austin19.tif',
#  'austin2.tif',
#  'austin20.tif',
#  'austin21.tif',
#  'austin22.tif',
#  'austin23.tif',
#  'austin24.tif',
#  'austin3.tif',
#  'austin4.tif',
#  'austin5.tif',
#  'austin6.tif',
#  'austin7.tif',
#  'austin8.tif',
#  'austin9.tif',
#  'chicago1.tif',
#  'chicago10.tif',
#  'chicago11.tif',
#  'chicago12.tif',
#  'chicago13.tif',
#  'chicago14.tif',
#  'chicago15.tif',
#  'chicago16.tif',
#  'chicago17.tif',
#  'chicago18.tif',
#  'chicago19.tif',
#  'chicago2.tif',
#  'chicago20.tif',
#  'chicago21.tif',
#  'chicago22.tif',
#  'chicago23.tif',
#  'chicago24.tif',
#  'chicago3.tif',
#  'chicago4.tif',
#  'chicago5.tif',
#  'chicago6.tif',
#  'chicago7.tif',
#  'chicago8.tif',
#  'chicago9.tif',
#  'kitsap1.tif',
#  'kitsap10.tif',
#  'kitsap11.tif',
#  'kitsap12.tif',
#  'kitsap13.tif',
#  'kitsap14.tif',
#  'kitsap15.tif',
#  'kitsap16.tif',
#  'kitsap17.tif',
#  'kitsap18.tif',
#  'kitsap19.tif',
#  'kitsap2.tif',
#  'kitsap20.tif',
#  'kitsap21.tif',
#  'kitsap22.tif',
#  'kitsap23.tif',
#  'kitsap24.tif',
#  'kitsap3.tif',
#  'kitsap4.tif',
#  'kitsap5.tif',
#  'kitsap6.tif',
#  'kitsap7.tif',
#  'kitsap8.tif',
#  'kitsap9.tif',
#  'tyrol-w1.tif',
#  'tyrol-w10.tif',
#  'tyrol-w11.tif',
#  'tyrol-w12.tif',
#  'tyrol-w13.tif',
#  'tyrol-w14.tif',
#  'tyrol-w15.tif',
#  'tyrol-w16.tif',
#  'tyrol-w17.tif',
#  'tyrol-w18.tif',
#  'tyrol-w19.tif',
#  'tyrol-w2.tif',
#  'tyrol-w20.tif',
#  'tyrol-w21.tif',
#  'tyrol-w22.tif',
#  'tyrol-w23.tif',
#  'tyrol-w24.tif',
#  'tyrol-w3.tif',
#  'tyrol-w4.tif',
#  'tyrol-w5.tif',
#  'tyrol-w6.tif',
#  'tyrol-w7.tif',
#  'tyrol-w8.tif',
#  'tyrol-w9.tif',
#  'vienna1.tif',
#  'vienna10.tif',
#  'vienna11.tif',
#  'vienna12.tif',
#  'vienna13.tif',
#  'vienna14.tif',
#  'vienna15.tif',
#  'vienna16.tif',
#  'vienna17.tif',
#  'vienna18.tif',
#  'vienna19.tif',
#  'vienna2.tif',
#  'vienna20.tif',
#  'vienna21.tif',
#  'vienna22.tif',
#  'vienna23.tif',
#  'vienna24.tif',
#  'vienna3.tif',
#  'vienna4.tif',
#  'vienna5.tif',
#  'vienna6.tif',
#  'vienna7.tif',
#  'vienna8.tif',
#  'vienna9.tif']

# %%
import imageio
image = np.random.choice(dataset.image_ids, 1)

# %%
plt.figure(figsize=(14,14))
plt.imshow( dataset.load_image(image[0]) )
plt.axis('off')
plt.title(image[0], fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.figure(figsize=(14,14))
plt.imshow( dataset.load_mask(image[0]) )
plt.axis('off')
plt.title(image[0], fontsize=20)
plt.show
# Out:
# /Users/sebastienohleyer/anaconda3/envs/objreco_namr/lib/python3.6/site-packages/imageio/plugins/_tifffile.py:4513: UserWarning: unexpected end of lzw stream (code 514)
#   warnings.warn("unexpected end of lzw stream (code %i)" % code)
# <function matplotlib.pyplot.show>
